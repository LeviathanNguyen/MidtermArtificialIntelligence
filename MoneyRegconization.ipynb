# %%
import numpy as np
import sklearn
import matplotlib.pyplot as plt
import cv2
from pathlib import Path

DATASETS_DIR = "./Datasets/Moneys/"

classnames = []

for path in Path(DATASETS_DIR).iterdir():
    if path.is_dir():
        classnames.append(str(path).split("/")[-1])

print(classnames)
# Out:
# ['10000', '20000', '5000', '50000']

# %%
X = []
y = []

for i in range(len(classnames)):
    print(classnames[i])
    images = list(Path(DATASETS_DIR + classnames[i]).glob("*"))
    for image in range(int(0.4 * len(images))):
        img = cv2.imread(str(images[image]))
        img = cv2.resize(img, (128, 128))
        img = img.astype("float32")
        img = img / 255
        X.append(img)
        y.append(i)
# Out:
# 10000
# 20000
# 5000
# 50000

# %%
from keras.utils import to_categorical
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(np.array(X), np.array(y), test_size=0.2)

y_train = to_categorical(y_train)
y_test = to_categorical(y_test)

print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# 2023-04-21 12:58:37.185391: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-04-21 12:58:37.446728: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-04-21 12:58:37.448354: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-04-21 12:58:39.348665: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# (963, 128, 128, 3)
# (241, 128, 128, 3)
# (963, 4)
# (241, 4)

# %%
plt.imshow(X_train[1])
print(y_train[1])
# Out:
# [1. 0. 0. 0.]

# %%
from keras.models import Sequential, Model
from keras import layers
from keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPooling2D, Activation

model = Sequential()

model.add(Conv2D(filters=32, kernel_size=(5, 5), padding="Same",
                 activation="relu", input_shape=X_train[0].shape))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(filters=64, kernel_size=(3, 3), padding="Same", activation="relu"))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(filters=96, kernel_size=(3, 3), padding="Same", activation="relu"))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(filters=96, kernel_size=(3, 3), padding="Same", activation="relu"))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Flatten())
model.add(Dense(1024))
model.add(Activation("relu"))
model.add(Dense(y_train.shape[1], activation="softmax"))

model.compile(loss="categorical_crossentropy", optimizer="adam",
              metrics=["accuracy"])
model.summary()

history = model.fit(X_train, y_train, epochs=50, batch_size=32, verbose=1)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 128, 128, 32)      2432
#
#  max_pooling2d (MaxPooling2D  (None, 64, 64, 32)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 64, 64, 64)        18496
#
#  max_pooling2d_1 (MaxPooling  (None, 32, 32, 64)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 32, 32, 96)        55392
#
#  max_pooling2d_2 (MaxPooling  (None, 16, 16, 96)       0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 16, 16, 96)        83040
#
#  max_pooling2d_3 (MaxPooling  (None, 8, 8, 96)         0
#  2D)
#
#  flatten (Flatten)           (None, 6144)              0
# 2023-04-21 12:59:13.360792: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-04-21 12:59:13.362841: W tensorflow/core/common_runtime/gpu/gpu_device.cc:1956] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
#
#  dense (Dense)               (None, 1024)              6292480
#
#  activation (Activation)     (None, 1024)              0
#
#  dense_1 (Dense)             (None, 4)                 4100
#
# =================================================================
# Total params: 6,455,940
# Trainable params: 6,455,940
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 2023-04-21 12:59:13.598889: W tensorflow/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 189333504 exceeds 10% of free system memory.
# 2023-04-21 12:59:15.596202: W tensorflow/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 67108864 exceeds 10% of free system memory.
# 2023-04-21 12:59:15.714059: W tensorflow/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 33554432 exceeds 10% of free system memory.
# 2023-04-21 12:59:16.145491: W tensorflow/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 33554432 exceeds 10% of free system memory.
# 2023-04-21 12:59:16.194620: W tensorflow/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 28311552 exceeds 10% of free system memory.
# 31/31 [==============================] - 29s 871ms/step - loss: 1.0285 - accuracy: 0.5057
# Epoch 2/50
# 31/31 [==============================] - 28s 914ms/step - loss: 0.2844 - accuracy: 0.8806
# Epoch 3/50
# 31/31 [==============================] - 25s 786ms/step - loss: 0.0434 - accuracy: 0.9896
# Epoch 4/50
# 31/31 [==============================] - 26s 846ms/step - loss: 0.0097 - accuracy: 0.9969
# Epoch 5/50
# 31/31 [==============================] - 26s 828ms/step - loss: 0.0159 - accuracy: 0.9938
# Epoch 6/50
# 31/31 [==============================] - 26s 829ms/step - loss: 0.0035 - accuracy: 1.0000
# Epoch 7/50
# 31/31 [==============================] - 26s 848ms/step - loss: 0.0011 - accuracy: 1.0000
# Epoch 8/50
# 31/31 [==============================] - 30s 970ms/step - loss: 1.1125e-04 - accuracy: 1.0000
# Epoch 9/50
# 31/31 [==============================] - 29s 928ms/step - loss: 5.0900e-05 - accuracy: 1.0000
# Epoch 10/50
# 31/31 [==============================] - 25s 802ms/step - loss: 3.0815e-05 - accuracy: 1.0000
# Epoch 11/50
# 31/31 [==============================] - 23s 758ms/step - loss: 2.3924e-05 - accuracy: 1.0000
# Epoch 12/50
# 31/31 [==============================] - 24s 776ms/step - loss: 1.9369e-05 - accuracy: 1.0000
# Epoch 13/50
# 31/31 [==============================] - 24s 771ms/step - loss: 1.6703e-05 - accuracy: 1.0000
# Epoch 14/50
# 31/31 [==============================] - 23s 733ms/step - loss: 1.4505e-05 - accuracy: 1.0000
# Epoch 15/50
# 31/31 [==============================] - 22s 709ms/step - loss: 1.3157e-05 - accuracy: 1.0000
# Epoch 16/50
# 31/31 [==============================] - 22s 722ms/step - loss: 1.1965e-05 - accuracy: 1.0000
# Epoch 17/50
# 31/31 [==============================] - 24s 761ms/step - loss: 1.0552e-05 - accuracy: 1.0000
# Epoch 18/50
# 31/31 [==============================] - 23s 752ms/step - loss: 9.6672e-06 - accuracy: 1.0000
# Epoch 19/50
# 31/31 [==============================] - 27s 886ms/step - loss: 8.9612e-06 - accuracy: 1.0000
# Epoch 20/50
# 31/31 [==============================] - 28s 917ms/step - loss: 8.2700e-06 - accuracy: 1.0000
# Epoch 21/50
# 31/31 [==============================] - 27s 879ms/step - loss: 7.6981e-06 - accuracy: 1.0000
# Epoch 22/50
# 31/31 [==============================] - 27s 856ms/step - loss: 7.1688e-06 - accuracy: 1.0000
# Epoch 23/50
# 31/31 [==============================] - 25s 802ms/step - loss: 6.6963e-06 - accuracy: 1.0000
# Epoch 24/50
# 31/31 [==============================] - 22s 724ms/step - loss: 6.3420e-06 - accuracy: 1.0000
# Epoch 25/50
# 31/31 [==============================] - 23s 757ms/step - loss: 5.8897e-06 - accuracy: 1.0000
# Epoch 26/50
# 31/31 [==============================] - 25s 808ms/step - loss: 5.5942e-06 - accuracy: 1.0000
# Epoch 27/50
# 31/31 [==============================] - 27s 871ms/step - loss: 5.9962e-06 - accuracy: 1.0000
# Epoch 28/50
# 31/31 [==============================] - 29s 947ms/step - loss: 4.9601e-06 - accuracy: 1.0000
# Epoch 29/50
# 31/31 [==============================] - 31s 1s/step - loss: 4.4977e-06 - accuracy: 1.0000
# Epoch 30/50
# 31/31 [==============================] - 30s 966ms/step - loss: 4.3168e-06 - accuracy: 1.0000
# Epoch 31/50
# 31/31 [==============================] - 30s 953ms/step - loss: 4.0267e-06 - accuracy: 1.0000
# Epoch 32/50
# 31/31 [==============================] - 30s 957ms/step - loss: 3.8296e-06 - accuracy: 1.0000
# Epoch 33/50
# 31/31 [==============================] - 28s 901ms/step - loss: 3.6170e-06 - accuracy: 1.0000
# Epoch 34/50
# 31/31 [==============================] - 28s 888ms/step - loss: 3.4869e-06 - accuracy: 1.0000
# Epoch 35/50
# 31/31 [==============================] - 28s 895ms/step - loss: 3.2572e-06 - accuracy: 1.0000
# Epoch 36/50
# 31/31 [==============================] - 28s 887ms/step - loss: 3.0987e-06 - accuracy: 1.0000
# Epoch 37/50
# 31/31 [==============================] - 28s 891ms/step - loss: 2.9523e-06 - accuracy: 1.0000
# Epoch 38/50
# 31/31 [==============================] - 28s 901ms/step - loss: 2.8477e-06 - accuracy: 1.0000
# Epoch 39/50
# 31/31 [==============================] - 28s 896ms/step - loss: 2.7044e-06 - accuracy: 1.0000
# Epoch 40/50
# 31/31 [==============================] - 27s 883ms/step - loss: 2.5841e-06 - accuracy: 1.0000
# Epoch 41/50
# 31/31 [==============================] - 28s 892ms/step - loss: 2.4524e-06 - accuracy: 1.0000
# Epoch 42/50
# 31/31 [==============================] - 28s 888ms/step - loss: 2.3655e-06 - accuracy: 1.0000
# Epoch 43/50
# 31/31 [==============================] - 28s 908ms/step - loss: 2.2428e-06 - accuracy: 1.0000
# Epoch 44/50
# 31/31 [==============================] - 27s 879ms/step - loss: 2.2116e-06 - accuracy: 1.0000
# Epoch 45/50
# 31/31 [==============================] - 27s 887ms/step - loss: 2.0513e-06 - accuracy: 1.0000
# Epoch 46/50
# 31/31 [==============================] - 27s 878ms/step - loss: 1.9583e-06 - accuracy: 1.0000
# Epoch 47/50
# 31/31 [==============================] - 28s 890ms/step - loss: 1.8846e-06 - accuracy: 1.0000
# Epoch 48/50
# 31/31 [==============================] - 27s 886ms/step - loss: 1.8396e-06 - accuracy: 1.0000
# Epoch 49/50
# 31/31 [==============================] - 28s 907ms/step - loss: 1.7353e-06 - accuracy: 1.0000
# Epoch 50/50
# 31/31 [==============================] - 28s 898ms/step - loss: 1.6592e-06 - accuracy: 1.0000

# %%
model.evaluate(X_test, y_test)
# Out:
# 8/8 [==============================] - 2s 175ms/step - loss: 8.7636e-06 - accuracy: 1.0000
# [8.763581718085334e-06, 1.0]

# %%
plt.plot(history.history["loss"], label="Training Loss")
plt.plot(history.history["accuracy"], label="Accuracy")
plt.title("Loss")
plt.xlabel("epochs")
plt.ylabel("loss")
plt.legend()
plt.show()

# %%
n = 1
print(X_test[n].shape)
plt.imshow(X_test[n])
predict = model.predict(X_test[n].reshape(1, 128, 128, 3))
print("Predict:", classnames[predict.argmax()])
print("True Label:", classnames[y_test[n].argmax()])
# Out:
# (128, 128, 3)
# 1/1 [==============================] - 0s 120ms/step
# Predict: 20000
# True Label: 20000

# %%
n += 1
print(X_test[n].shape)
plt.imshow(X_test[n])
predict = model.predict(X_test[n].reshape(1, 128, 128, 3))
print("Predict:", classnames[predict.argmax()])
print("True Label:", classnames[y_test[n].argmax()])
# Out:
# (128, 128, 3)
# 1/1 [==============================] - 0s 33ms/step
# Predict: 10000
# True Label: 10000

# %%
n += 1
print(X_test[n].shape)
plt.imshow(X_test[n])
predict = model.predict(X_test[n].reshape(1, 128, 128, 3))
print("Predict:", classnames[predict.argmax()])
print("True Label:", classnames[y_test[n].argmax()])
# Out:
# (128, 128, 3)
# 1/1 [==============================] - 0s 28ms/step
# Predict: 20000
# True Label: 20000

# %%
n += 1
print(X_test[n].shape)
plt.imshow(X_test[n])
predict = model.predict(X_test[n].reshape(1, 128, 128, 3))
print("Predict:", classnames[predict.argmax()])
print("True Label:", classnames[y_test[n].argmax()])
# Out:
# (128, 128, 3)
# 1/1 [==============================] - 0s 92ms/step
# Predict: 50000
# True Label: 50000

# %%
n += 1
print(X_test[n].shape)
plt.imshow(X_test[n])
predict = model.predict(X_test[n].reshape(1, 128, 128, 3))
print("Predict:", classnames[predict.argmax()])
print("True Label:", classnames[y_test[n].argmax()])
# Out:
# (128, 128, 3)
# 1/1 [==============================] - 0s 28ms/step
# Predict: 20000
# True Label: 20000

# %%
n += 1
print(X_test[n].shape)
plt.imshow(X_test[n])
predict = model.predict(X_test[n].reshape(1, 128, 128, 3))
print("Predict:", classnames[predict.argmax()])
print("True Label:", classnames[y_test[n].argmax()])
# Out:
# (128, 128, 3)
# 1/1 [==============================] - 0s 32ms/step
# Predict: 50000
# True Label: 50000

# %%
n += 1
print(X_test[n].shape)
plt.imshow(X_test[n])
predict = model.predict(X_test[n].reshape(1, 128, 128, 3))
print("Predict:", classnames[predict.argmax()])
print("True Label:", classnames[y_test[n].argmax()])
# Out:
# (128, 128, 3)
# 1/1 [==============================] - 0s 30ms/step
# Predict: 50000
# True Label: 50000

# %%
n += 1
print(X_test[n].shape)
plt.imshow(X_test[n])
predict = model.predict(X_test[n].reshape(1, 128, 128, 3))
print("Predict:", classnames[predict.argmax()])
print("True Label:", classnames[y_test[n].argmax()])
# Out:
# (128, 128, 3)
# 1/1 [==============================] - 0s 35ms/step
# Predict: 20000
# True Label: 20000

# %%
n += 1
print(X_test[n].shape)
plt.imshow(X_test[n])
predict = model.predict(X_test[n].reshape(1, 128, 128, 3))
print("Predict:", classnames[predict.argmax()])
print("True Label:", classnames[y_test[n].argmax()])
# Out:
# (128, 128, 3)
# 1/1 [==============================] - 0s 27ms/step
# Predict: 50000
# True Label: 50000

# %%
n += 1
print(X_test[n].shape)
plt.imshow(X_test[n])
predict = model.predict(X_test[n].reshape(1, 128, 128, 3))
print("Predict:", classnames[predict.argmax()])
print("True Label:", classnames[y_test[n].argmax()])
# Out:
# (128, 128, 3)
# 1/1 [==============================] - 0s 76ms/step
# Predict: 20000
# True Label: 20000
